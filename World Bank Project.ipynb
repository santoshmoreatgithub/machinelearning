# %% [markdown]
# ## This project to use WORLD BANK DEVELOPMENT INDICATORS data to compare UK Singapore China India and Pakistan

# %%
# Initiallize the enviornment 
# !pip install wbdata
import wbdata
import pandas
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ...
# You are using pip version 19.0.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ### GNI per Capita

# %%
# Select the countries
countries = ["IN","PK","CN","SG","GB"]

# Select the indicators
indicator1 = {'NY.GNP.PCAP.CD':'GNI per Capita'}
 
# Grab indicators for countires and load into data frame
df1 = wbdata.get_dataframe(indicator1, country=countries, convert_date=False)

#df is "pivoted", pandas' unstack fucntion helps reshape it into something plottable
dfu1 = df1.unstack(level=0)

# a simple matplotlib plot with legend, labels and a title
dfu1.plot(); 
plt.legend(loc='best');

# %% [markdown]
# ### Urban population (% of total population)

# %%
# Select the indicators
indicator2 = {'SP.URB.TOTL.IN.ZS':'Ubrn ppln %'}
 
# Grab indicators for countires and load into data frame
df2 = wbdata.get_dataframe(indicator2, country=countries, convert_date=False)

#df is "pivoted", pandas' unstack fucntion helps reshape it into something plottable
dfu2 = df2.unstack(level=0)

# a simple matplotlib plot with legend, labels and a title
dfu2.plot(); 
plt.legend(loc='best');

# %% [markdown]
# ### Unemployment %

# %%
# Select the indicators
indicator3 = {'SL.UEM.TOTL.ZS':'Unemployment %'}
 
# Grab indicators for countires and load into data frame
df3 = wbdata.get_dataframe(indicator3, country=countries, convert_date=False)

#df is "pivoted", pandas' unstack fucntion helps reshape it into something plottable
dfu3 = df3.unstack(level=0)

# a simple matplotlib plot with legend, labels and a title
dfu3.plot(); 
plt.legend(loc='best');

# %% [markdown]
# ### Self-employed %

# %%
# Select the indicators
indicator4 = {'SL.EMP.SELF.ZS':'Self-employed %'}
 
# Grab indicators for countires and load into data frame
df4 = wbdata.get_dataframe(indicator4, country=countries, convert_date=False)

#df is "pivoted", pandas' unstack fucntion helps reshape it into something plottable
dfu4 = df4.unstack(level=0)

# a simple matplotlib plot with legend, labels and a title
dfu4.plot(); 
plt.legend(loc='best');

# %% [markdown]
# ### Total reserves

# %%
# Select the indicators
indicator5 = {'FI.RES.TOTL.CD':'Total reserves'}
 
# Grab indicators for countires and load into data frame
df5 = wbdata.get_dataframe(indicator5, country=countries, convert_date=False)

#df is "pivoted", pandas' unstack fucntion helps reshape it into something plottable
dfu5 = df5.unstack(level=0)

# a simple matplotlib plot with legend, labels and a title
dfu5.plot(); 
plt.legend(loc='best');

# %% [markdown]
# ### Mobile cellular subscriptions (per 100 people)

# %%
# Select the indicators
indicator6 = {'IT.CEL.SETS.P2':'Mobile subs %'}
 
# Grab indicators for countires and load into data frame
df6 = wbdata.get_dataframe(indicator6, country=countries, convert_date=False)

#df is "pivoted", pandas' unstack fucntion helps reshape it into something plottable
dfu6 = df6.unstack(level=0)

# a simple matplotlib plot with legend, labels and a title
dfu6.plot(); 
plt.legend(loc='best');

# %% [markdown]
# ### Foreign direct investment, net inflows (BoP, current US$)

# %%
# Select the indicators
indicator7 = {'BX.KLT.DINV.CD.WD':'Forgn drct investment)'}
 
# Grab indicators for countires and load into data frame
df7 = wbdata.get_dataframe(indicator7, country=countries, convert_date=False)

#df is "pivoted", pandas' unstack fucntion helps reshape it into something plottable
dfu7 = df7.unstack(level=0)

# a simple matplotlib plot with legend, labels and a title
dfu7.plot(); 
plt.legend(loc='best');

# %% [markdown]
# ### Foreign direct investment, net inflows (% of GDP)

# %%
# Select the indicators
indicator8 = {'BX.KLT.DINV.WD.GD.ZS':'Frgn drct investmentr'}
 
# Grab indicators for countires and load into data frame
df8 = wbdata.get_dataframe(indicator8, country=countries, convert_date=False)

#df is "pivoted", pandas' unstack fucntion helps reshape it into something plottable
dfu8 = df8.unstack(level=0)

# a simple matplotlib plot with legend, labels and a title
dfu8.plot(); 
plt.legend(loc='best');

# %% [markdown]
# ### Employment to population ratio, 15+, total (%) (modeled ILO estimate)

# %%
# Select the indicators
indicator8 = {'SL.EMP.TOTL.SP.ZS':'Emplmnt to ppln ratio'}
 
# Grab indicators for countires and load into data frame
df8 = wbdata.get_dataframe(indicator8, country=countries, convert_date=False)

#df is "pivoted", pandas' unstack fucntion helps reshape it into something plottable
dfu8 = df8.unstack(level=0)

# a simple matplotlib plot with legend, labels and a title
dfu8.plot(); 
plt.legend(loc='best');
